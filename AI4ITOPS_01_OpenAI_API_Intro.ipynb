# %% [markdown]
# <a href="https://colab.research.google.com/github/karuntech/ai_for_it_operations/blob/main/AI4ITOPS_01_OpenAI_API_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This coloab notebook guides you to write your first generative AI program in python using OpenAI API.
#
# You must obtain an API Key from OpenAI (platform.openai.com) and add the key as a secret in google colab. The name of the key must be OPENAI_API_KEY.
#
# ![image.png](data:image/png;base64,...)

# %%
# install openapi python package

# !pip install openai

# %%
from google.colab import userdata
from openai import OpenAI
import os

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

client = OpenAI()

response = client.responses.create(
    model="gpt-4o",
    input="Give a 10–20 word description of AWS ALB and NLB, and present a comparison in a table."
)

print(response.output_text)
# Out:
# **AWS ALB and NLB:**
#
# - **ALB**: Application Load Balancer distributes traffic at the application layer and supports advanced routing.
# - **NLB**: Network Load Balancer operates at the transport layer, handling millions of requests with ultra-low latency.
#
# | Feature                | Application Load Balancer (ALB)    | Network Load Balancer (NLB)       |
# |------------------------|------------------------------------|-----------------------------------|
# | Layer                  | Application (Layer 7)              | Transport (Layer 4)               |
# | Routing                | Advanced HTTP/HTTPS routing        | Basic TCP/UDP routing             |
# | Latency                | Higher latency                     | Ultra-low latency                 |
# | Protocols Supported    | HTTP, HTTPS, WebSocket             | TCP, UDP, TLS                     |
# | Use Case               | Web applications                   | High-performance, real-time apps  |
# ...
