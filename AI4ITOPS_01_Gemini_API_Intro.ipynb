# %% [markdown]
# <a href="https://colab.research.google.com/github/karuntech/ai_for_it_operations/blob/main/AI4ITOPS_01_Gemini_API_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This coloab notebook guides you to write your first **generative AI** program in python using Gemini API.
#
# You must obtain an API Key from Google AI Studio (https://aistudio.google.com/) and add the key as a secret in google colab. The name of the key must be GEMINI_API_KEY.
#
# ![Screenshot 2025-11-09 at 8.30.30 PM.png](data:image/png;base64,...)

# %%
from google.colab import userdata
from google import genai
import os

os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')

# Initalize Gemini client

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Give a 10–20 word description of AWS ALB and NLB, and present a comparison in a table."
)

print(response.text)
# Out:
# Here are 10-20 word descriptions for AWS ALB and NLB, followed by a comparison table:
#
# **AWS ALB (Application Load Balancer):**
# Layer 7 load balancer (HTTP/S) for web applications, offering advanced content-based routing, path, and host rules.
#
# **AWS NLB (Network Load Balancer):**
# Layer 4 load balancer (TCP/UDP) for extreme performance, ultra-low latency, and preserving client IP for critical workloads.
#
# ---
#
# ### AWS ALB vs. NLB Comparison
#
# | Feature             | AWS ALB (Application Load Balancer)                                     | AWS NLB (Network Load Balancer)                                      |
# | :------------------ | :---------------------------------------------------------------------- | :------------------------------------------------------------------- |
# | **Operating Layer** | Layer 7 (Application Layer)                                             | Layer 4 (Transport Layer)                                            |
# ...
